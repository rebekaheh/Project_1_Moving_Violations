# %%
import pandas as pd
import glob

# %%
# Input a path to my Git Folder which contains the CSVs

path = (r"C:\Users\RebekahDSK\Desktop\Project_1_Moving_Violations\2019 Monthly CSVs")
CSVFiles = glob.glob(path + "/*.csv")

# %%
# Create a list to hold data from all 2019 CSV files

list_data = []

# %%
# Create a loop which adds each CSV file in the 'Path' folder into the 'list_data' list

for filename in CSVFiles:
    df = pd.read_csv(filename, index_col=None, header=0)
    list_data.append(df)
# Out:
# C:\Users\RebekahDSK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\RebekahDSK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\RebekahDSK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Create a DataFrame containing all the CSV files (for every available month of 2019)
all_data_twozeroonenine_df = pd.concat(list_data, axis=0, ignore_index=True)

# Print a preview of the DataFrame
all_data_twozeroonenine_df.head(5)
# Out:
#    OBJECTID                 LOCATION     XCOORD     YCOORD  \
# 0      8730       1400 BRANCH AVE SE  403440.57  133762.28
# 1      8731      I-295 ANACOSTIA FWY        NaN        NaN
# 2     10053  I 395 N/B HOV BRIDGE SW        NaN        NaN
# 3     10054           1000 6TH ST NW  398273.55  137243.91
# 4     10055           1000 6TH ST NW  398273.55  137243.91
#
#                ISSUE_DATE ISSUE_TIME  ISSUING_AGENCY_CODE  \
# 0  2019/04/29 04:00:00+00    1:30:00                  6.0
# 1  2019/04/01 04:00:00+00    9:55:00                  6.0
# 2  2019/04/18 04:00:00+00    4:20:00                  1.0
# 3  2019/04/23 04:00:00+00    3:00:00                  1.0
# 4  2019/04/23 04:00:00+00    3:00:00                  1.0
#
#                   ISSUING_AGENCY_NAME ISSUING_AGENCY_SHORT VIOLATION_CODE  \
# 0  METROPOLITAN POLICE DPT-DISTRICT 6               MPD-6D           T043
# 1  METROPOLITAN POLICE DPT-DISTRICT 6               MPD-6D           T043
# 2  METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D           T335
# 3  METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D           T335
# 4  METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D           T667
#
#    ... LATITUDE LONGITUDE    MAR_ID       GIS_LAST_MOD_DTTM DRV_LIC_STATE  \
# 0  ...   38.872    -76.96  307585.0  2020/09/30 03:44:25+00            DC
# 1  ...      NaN       NaN       NaN  2020/09/30 03:44:25+00            DC
# 2  ...      NaN       NaN       NaN  2020/09/30 03:44:25+00            VA
# 3  ...   38.903    -77.02  807095.0  2020/09/30 03:44:25+00            DC
# 4  ...   38.903    -77.02  807095.0  2020/09/30 03:44:25+00            DC
#
#   DOB_YEAR  VEH_YEAR  VEH_MAKE  TICKET_NUMBER  VIOLATION_TYPE_DESC
# 0   1985.0       NaN      CHRY            NaN                  NaN
# 1   1972.0       NaN      HOND            NaN                  NaN
# 2   1987.0       NaN      MAZD            NaN                  NaN
# 3   1993.0       NaN      TOYO            NaN                  NaN
# 4   1993.0       NaN      TOYO            NaN                  NaN
#
# [5 rows x 35 columns]

# %%
# Let's see what columns we're working with

all_data_twozeroonenine_df.columns
# Out:
# Index(['OBJECTID', 'LOCATION', 'XCOORD', 'YCOORD', 'ISSUE_DATE', 'ISSUE_TIME',
#        'ISSUING_AGENCY_CODE', 'ISSUING_AGENCY_NAME', 'ISSUING_AGENCY_SHORT',
#        'VIOLATION_CODE', 'VIOLATION_PROCESS_DESC', 'PLATE_STATE',
#        'ACCIDENT_INDICATOR', 'DISPOSITION_CODE', 'DISPOSITION_TYPE',
#        'DISPOSITION_DATE', 'FINE_AMOUNT', 'TOTAL_PAID', 'PENALTY_1',
#        'PENALTY_2', 'PENALTY_3', 'PENALTY_4', 'PENALTY_5', 'RP_MULT_OWNER_NO',
#        'BODY_STYLE', 'LATITUDE', 'LONGITUDE', 'MAR_ID', 'GIS_LAST_MOD_DTTM',
#        'DRV_LIC_STATE', 'DOB_YEAR', 'VEH_YEAR', 'VEH_MAKE', 'TICKET_NUMBER',
#        'VIOLATION_TYPE_DESC'],
#       dtype='object')

# %%
# Clean up the DataFrame to include only the columns we need for analysis

clean_twozeroonenine_df = all_data_twozeroonenine_df.iloc[:, [0, 1, 4, 5, 7, 8, 9, 10, 11, 12, 16, 29, 30, 32]]
clean_twozeroonenine_df

# The resulting DataFrame includes all 11 months (February being our caveat), 1201351 rows, and 14 columns
# Out:
#          OBJECTID                         LOCATION              ISSUE_DATE  \
# 0            8730               1400 BRANCH AVE SE  2019/04/29 04:00:00+00
# 1            8731              I-295 ANACOSTIA FWY  2019/04/01 04:00:00+00
# 2           10053          I 395 N/B HOV BRIDGE SW  2019/04/18 04:00:00+00
# 3           10054                   1000 6TH ST NW  2019/04/23 04:00:00+00
# 4           10055                   1000 6TH ST NW  2019/04/23 04:00:00+00
# ...           ...                              ...                     ...
# 1201346   9187235  E Capitol St e/b @ Texas Ave SE  2019/09/29 04:00:00+00
# 1201347   9187236  E Capitol St e/b @ Texas Ave SE  2019/09/29 04:00:00+00
# 1201348   9187237  E Capitol St e/b @ Texas Ave SE  2019/09/29 04:00:00+00
# 1201349   9187238  E Capitol St e/b @ Texas Ave SE  2019/09/29 04:00:00+00
# 1201350   9187239  E Capitol St e/b @ Texas Ave SE  2019/09/30 04:00:00+00
#
#         ISSUE_TIME                  ISSUING_AGENCY_NAME ISSUING_AGENCY_SHORT  \
# 0          1:30:00   METROPOLITAN POLICE DPT-DISTRICT 6               MPD-6D
# 1          9:55:00   METROPOLITAN POLICE DPT-DISTRICT 6               MPD-6D
# 2          4:20:00   METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D
# 3          3:00:00   METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D
# 4          3:00:00   METROPOLITAN POLICE DPT-DISTRICT 1               MPD-1D
# ...            ...                                  ...                  ...
# 1201346    2:46:00  SPECIAL OPERATION DIV & TRAFFIC DIV              MPD-SOD
# 1201347    2:59:00  SPECIAL OPERATION DIV & TRAFFIC DIV              MPD-SOD
# 1201348    3:49:00  SPECIAL OPERATION DIV & TRAFFIC DIV              MPD-SOD
# 1201349    4:49:00  SPECIAL OPERATION DIV & TRAFFIC DIV              MPD-SOD
# 1201350    8:40:00  SPECIAL OPERATION DIV & TRAFFIC DIV              MPD-SOD
#
#         VIOLATION_CODE                            VIOLATION_PROCESS_DESC  \
# 0                 T043                      FOLLOW A VEHICLE TOO CLOSELY
# 1                 T043                      FOLLOW A VEHICLE TOO CLOSELY
# 2                 T335  FAIL TO CONTROL VEHICLE SPEED TO AVOID COLLIDING
# 3                 T335  FAIL TO CONTROL VEHICLE SPEED TO AVOID COLLIDING
# 4                 T667                              DEAD OR EXPIRED TAGS
# ...                ...                                               ...
# 1201346           T119              SPEED 11-15 MPH OVER THE SPEED LIMIT
# 1201347           T121              SPEED 21-25 MPH OVER THE SPEED LIMIT
# 1201348           T119              SPEED 11-15 MPH OVER THE SPEED LIMIT
# 1201349           T119              SPEED 11-15 MPH OVER THE SPEED LIMIT
# 1201350           T119              SPEED 11-15 MPH OVER THE SPEED LIMIT
#
#         PLATE_STATE ACCIDENT_INDICATOR  FINE_AMOUNT DRV_LIC_STATE  DOB_YEAR  \
# 0                DC                  N        100.0            DC    1985.0
# 1                DC                  N         75.0            DC    1972.0
# 2                VA                  Y        100.0            VA    1987.0
# 3                DC                  Y        150.0            DC    1993.0
# 4                DC                  Y        100.0            DC    1993.0
# ...             ...                ...          ...           ...       ...
# 1201346                            NaN        100.0           NaN       NaN
# 1201347                            NaN        200.0           NaN       NaN
# 1201348                            NaN        100.0           NaN       NaN
# 1201349                            NaN        100.0            DC    1965.0
# 1201350                            NaN        100.0           NaN       NaN
#
#         VEH_MAKE
# 0           CHRY
# 1           HOND
# 2           MAZD
# 3           TOYO
# 4           TOYO
# ...          ...
# 1201346      RAM
# 1201347     HOND
# 1201348     ACUR
# 1201349     HOND
# 1201350     NISS
#
# [1201351 rows x 14 columns]
